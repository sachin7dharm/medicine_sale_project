# %% [markdown]
# This dataset is downloded from Kaggle https://www.kaggle.com/datasets/shivamkapoor5034/pharmaceutical-monthly-sales?select=MedicineData.csv
#
# The dataset contains monthly sales of the drug R03 in the United States (in millions of US $) between 1992 and 2018.
# R03 - Drugs for obstructive airway diseases.
# Sales data are resampled to the monthly periods.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\sachi\Downloads\archive (11)\archive (4)\MedicineData.csv")
df
# Out:
#           date   R03
# 0     1/1/1992  1509
# 1     2/1/1992  1541
# 2     3/1/1992  1597
# 3     4/1/1992  1675
# 4     5/1/1992  1822
# ..         ...   ...
# 319   8/1/2018  4898
# 320   9/1/2018  4598
# 321  10/1/2018  4737
# 322  11/1/2018  5130
# 323  12/1/2018  6370
#
# [324 rows x 2 columns]

# %%
# top rows

df.head()
# Out:
#        date   R03
# 0  1/1/1992  1509
# 1  2/1/1992  1541
# 2  3/1/1992  1597
# 3  4/1/1992  1675
# 4  5/1/1992  1822

# %%
# last rows

df.tail()
# Out:
#           date   R03
# 319   8/1/2018  4898
# 320   9/1/2018  4598
# 321  10/1/2018  4737
# 322  11/1/2018  5130
# 323  12/1/2018  6370

# %%
# data information 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    324 non-null    object
#  1   R03     324 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.2+ KB

# %%
#  checking null values

df.isnull().sum()
# Out:
# date    0
# R03     0
# dtype: int64

# %%
# coverting date column into date dat type

df['date'] = pd.to_datetime(df['date'])
df
# Out:
#           date   R03
# 0   1992-01-01  1509
# 1   1992-02-01  1541
# 2   1992-03-01  1597
# 3   1992-04-01  1675
# 4   1992-05-01  1822
# ..         ...   ...
# 319 2018-08-01  4898
# 320 2018-09-01  4598
# 321 2018-10-01  4737
# 322 2018-11-01  5130
# 323 2018-12-01  6370
#
# [324 rows x 2 columns]

# %%
#creating new column named year

df['year'] = df['date'].dt.year
df['month']=df['date'].dt.month_name()
df
# Out:
#           date   R03  year      month
# 0   1992-01-01  1509  1992    January
# 1   1992-02-01  1541  1992   February
# 2   1992-03-01  1597  1992      March
# 3   1992-04-01  1675  1992      April
# 4   1992-05-01  1822  1992        May
# ..         ...   ...   ...        ...
# 319 2018-08-01  4898  2018     August
# 320 2018-09-01  4598  2018  September
# 321 2018-10-01  4737  2018    October
# 322 2018-11-01  5130  2018   November
# 323 2018-12-01  6370  2018   December
#
# [324 rows x 4 columns]

# %%
# year wise sale

ydf=df.groupby('year')['R03'].sum().reset_index()
sns.lineplot(x='year',y='R03',data=ydf,marker='o')
plt.grid()
plt.title('Year wise Sale')

plt.show()

# %%
# year wise average sale

avg_ydf=df.groupby('year')['R03'].mean().reset_index()
sns.lineplot(x='year',y='R03',data=avg_ydf,marker='o')
plt.grid()
plt.title('Year wise Average Sale')

plt.show()

# %%
# month wise total sale from 1992 to 2018

mdf=df.groupby(['month'])['R03'].sum().sort_values().reset_index()
sns.barplot(x='R03',y='month',data=mdf)
plt.show()

# %%
# year and month wise sale

ymdf=df.groupby(['year','month'])['R03'].sum().reset_index()
sns.lineplot(x='year',y='R03',hue='month',data=ymdf)
plt.grid()
plt.show()
